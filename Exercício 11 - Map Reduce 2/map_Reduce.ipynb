# %%
from collections import Counter
from functools import reduce

import glob
import os


def conta_um_arquivo(fpath):
    lista_palavras = []
    with open(fpath, encoding="utf8") as input_file:
        for line in input_file:
            line = line.lower().strip()
            if line:
                palavras = line.split()
                for i in palavras:
                    lista_palavras.append(i)
    return Counter(lista_palavras)

def reduz(contagens_1, contagens_2):
    return contagens_1 + contagens_2

def main():
    pasta =  os.path.join('.', 'dados', '*.txt')
    resultado = reduce(reduz, map(conta_um_arquivo, glob.glob(pasta)))
    return resultado
    
if __name__ == '__main__':
    main()

# %%
pasta = os.path.join('.','dados','*.txt')
glob.glob(pasta)
# Out:
# ['.\\dados\\Alice.txt',
#  '.\\dados\\MonsterMaker.txt',
#  '.\\dados\\PridePrejudice.txt',
#  '.\\dados\\SherlockHolmes.txt',
#  '.\\dados\\YellowWallpaper.txt']

# %%
resultadomap = list(map(conta_um_arquivo, glob.glob(pasta)))

resultadofinal = reduce(reduz, map(conta_um_arquivo, glob.glob(pasta)))

# %%
resultadomap = list(map(conta_um_arquivo, glob.glob(pasta)))

# %%
resultadomap
# Out:
# [Counter({'the': 1791,
#           'project': 83,
#           'gutenberg': 24,
#           'ebook': 8,
#           'of': 614,
#           'alice’s': 16,
#           'adventures': 9,
#           'in': 415,
#           'wonderland,': 3,
#           'by': 85,
#           'lewis': 4,
#           'carroll': 4,
#           'this': 149,
#           'is': 86,
#           'for': 161,
#           'use': 27,
#           'anyone': 4,
#           'anywhere': 3,
#           'at': 217,
#           'no': 76,
#           'cost': 3,
#           'and': 837,
#           'with': 218,
#           'almost': 8,
#           'restrictions': 2,
#           'whatsoever.': 2,
#           'you': 327,
#           'may': 27,
#           'copy': 8,
#           'it,': 41,
#           'give': 13,
#           'it': 374,
#           'away': 17,
#           'or': 143,
#           're-use': 2,
#           'under': 22,
#           'terms': 22,
#           'license': 11,
#           'included': 2,
#           'online': 4,
#           'www.gutenberg.org': 3,
#           'title:': 1,
#           'wonderland': 5,
#           'author:': 1,
#           'release': 1,
#           'date:': 1,
#           'june': 1,
#           '25,': 1,
#           '2008': 1,
#           '[ebook': 1,
#           '#11]': 1,
#           'last': 27,
#           'updated:': 1,
#           'february': 1,
#           '22,': 1,
#           '2020': 1,
#           'language:': 1,
#           'english': 2,
#           'character': 1,
#           'set': 23,
#           'encoding:': 1,
#           'utf-8': 1,
#           '***': 4,
#           'start': 2,
#           'produced': 4,
#           'arthur': 2,
#           'dibianca': 2,
#           'david': 2,
#           'widger': 2,
#           '[illustration]': 1,
#           'millennium': 1,
#           'fulcrum': 1,
#           'edition': 1,
#           '3.0': 1,
#           'contents': 1,
#           'chapter': 24,
#           'i.': 2,
#           'down': 79,
#           'rabbit-hole': 4,
#           'ii.': 2,
#           'pool': 8,
#           'tears': 6,
#           'iii.': 2,
#           'a': 675,
#           'caucus-race': 2,
#           'long': 32,
#           'tale': 3,
#           'iv.': 2,
#           'rabbit': 31,
#           'sends': 2,
#           'little': 120,
#           'bill': 3,
#           'v.': 2,
#           'advice': 2,
#           'from': 47,
#           'caterpillar': 12,
#           'vi.': 2,
#           'pig': 2,
#           'pepper': 7,
#           'vii.': 2,
#           'mad': 7,
#           'tea-party': 3,
#           'viii.': 2,
#           'queen’s': 8,
#           'croquet-ground': 3,
#           'ix.': 2,
#           'mock': 57,
#           'turtle’s': 3,
#           'story': 4,
#           'x.': 2,
#           'lobster': 6,
#           'quadrille': 3,
#           'xi.': 2,
#           'who': 58,
#           'stole': 3,
#           'tarts?': 2,
#           'xii.': 2,
#           'evidence': 5,
#           'alice': 221,
#           'was': 330,
#           'beginning': 12,
#           'to': 783,
#           'get': 43,
#           'very': 127,
#           'tired': 7,
#           'sitting': 10,
#           'her': 207,
#           'sister': 5,
#           'on': 152,
#           'bank,': 2,
#           'having': 10,
#           'nothing': 22,
#           'do:': 1,
#           'once': 19,
#           'twice': 1,
#           'she': 518,
#           'had': 176,
#           'peeped': 3,
#           'into': 67,
#           'book': 3,
#           'reading,': 1,
#           'but': 121,
#           'pictures': 4,
#           'conversations': 1,
#           '“and': 55,
#           'what': 90,
#           'book,”': 2,
#           'thought': 63,
#           '“without': 1,
#           'conversations?”': 1,
#           'so': 127,
#           'considering': 3,
#           'own': 9,
#           'mind': 5,
#           '(as': 3,
#           'well': 27,
#           'as': 258,
#           'could,': 7,
#           'hot': 4,
#           'day': 11,
#           'made': 29,
#           'feel': 8,
#           'sleepy': 3,
#           'stupid),': 1,
#           'whether': 11,
#           'pleasure': 2,
#           'making': 8,
#           'daisy-chain': 1,
#           'would': 71,
#           'be': 157,
#           'worth': 4,
#           'trouble': 4,
#           'getting': 21,
#           'up': 83,
#           'picking': 2,
#           'daisies,': 1,
#           'when': 74,
#           'suddenly': 10,
#           'white': 28,
#           'pink': 1,
#           'eyes': 18,
#           'ran': 13,
#           'close': 12,
#           'her.': 13,
#           'there': 65,
#           '_very_': 13,
#           'remarkable': 2,
#           'that;': 1,
#           'nor': 2,
#           'did': 50,
#           'think': 36,
#           'much': 41,
#           'out': 98,
#           'way': 39,
#           'hear': 15,
#           'say': 35,
#           'itself,': 4,
#           '“oh': 2,
#           'dear!': 9,
#           'oh': 6,
#           'i': 249,
#           'shall': 24,
#           'late!”': 1,
#           '(when': 1,
#           'over': 31,
#           'afterwards,': 1,
#           'occurred': 2,
#           'that': 231,
#           'ought': 13,
#           'have': 79,
#           'wondered': 1,
#           'this,': 17,
#           'time': 47,
#           'all': 172,
#           'seemed': 27,
#           'quite': 53,
#           'natural);': 1,
#           'actually': 1,
#           '_took': 1,
#           'watch': 6,
#           'its': 62,
#           'waistcoat-pocket_,': 1,
#           'looked': 45,
#           'then': 59,
#           'hurried': 11,
#           'on,': 28,
#           'started': 2,
#           'feet,': 6,
#           'flashed': 1,
#           'across': 5,
#           'never': 38,
#           'before': 22,
#           'seen': 12,
#           'either': 7,
#           'waistcoat-pocket,': 1,
#           'take': 19,
#           'burning': 1,
#           'curiosity,': 2,
#           'field': 1,
#           'after': 40,
#           'fortunately': 1,
#           'just': 48,
#           'see': 51,
#           'pop': 1,
#           'large': 32,
#           'hedge.': 1,
#           'another': 21,
#           'moment': 21,
#           'went': 79,
#           'how': 50,
#           'world': 7,
#           'again.': 16,
#           'straight': 2,
#           'like': 75,
#           'tunnel': 1,
#           'some': 50,
#           'way,': 7,
#           'dipped': 2,
#           'down,': 14,
#           'not': 130,
#           'about': 92,
#           'stopping': 1,
#           'herself': 40,
#           'found': 31,
#           'falling': 2,
#           'deep': 5,
#           'well.': 2,
#           'deep,': 2,
#           'fell': 6,
#           'slowly,': 2,
#           'plenty': 1,
#           'look': 25,
#           'wonder': 15,
#           'going': 26,
#           'happen': 5,
#           'next.': 3,
#           'first,': 11,
#           'tried': 18,
#           'make': 29,
#           'coming': 5,
#           'to,': 7,
#           'too': 21,
#           'dark': 3,
#           'anything;': 2,
#           'sides': 4,
#           'well,': 1,
#           'noticed': 7,
#           'they': 120,
#           'were': 82,
#           'filled': 3,
#           'cupboards': 2,
#           'book-shelves;': 1,
#           'here': 19,
#           'saw': 13,
#           'maps': 1,
#           'hung': 1,
#           'upon': 28,
#           'pegs.': 1,
#           'took': 23,
#           'jar': 2,
#           'one': 79,
#           'shelves': 1,
#           'passed;': 1,
#           'labelled': 1,
#           '“orange': 1,
#           'marmalade”,': 1,
#           'great': 39,
#           'disappointment': 1,
#           'empty:': 1,
#           'drop': 1,
#           'fear': 4,
#           'killing': 1,
#           'somebody': 4,
#           'underneath,': 1,
#           'managed': 3,
#           'put': 31,
#           'past': 1,
#           'it.': 15,
#           '“well!”': 1,
#           'herself,': 31,
#           '“after': 2,
#           'such': 46,
#           'fall': 6,
#           'tumbling': 2,
#           'stairs!': 1,
#           'brave': 1,
#           'they’ll': 4,
#           'me': 46,
#           'home!': 1,
#           'why,': 9,
#           'wouldn’t': 12,
#           'anything': 16,
#           'even': 20,
#           'if': 92,
#           'off': 40,
#           'top': 8,
#           'house!”': 1,
#           '(which': 3,
#           'likely': 4,
#           'true.)': 1,
#           'down.': 2,
#           '_never_': 2,
#           'come': 26,
#           'an': 60,
#           'end?': 1,
#           '“i': 119,
#           'many': 14,
#           'miles': 3,
#           'i’ve': 20,
#           'fallen': 4,
#           'time?”': 1,
#           'said': 420,
#           'aloud.': 3,
#           'must': 48,
#           'somewhere': 1,
#           'near': 14,
#           'centre': 1,
#           'earth.': 2,
#           'let': 13,
#           'see:': 3,
#           'four': 6,
#           'thousand': 2,
#           'think—”': 3,
#           '(for,': 2,
#           'see,': 11,
#           'learnt': 2,
#           'several': 5,
#           'things': 21,
#           'sort': 17,
#           'lessons': 4,
#           'schoolroom,': 1,
#           'though': 7,
#           'good': 23,
#           'opportunity': 9,
#           'showing': 2,
#           'knowledge,': 1,
#           'listen': 4,
#           'her,': 18,
#           'still': 13,
#           'practice': 1,
#           'over)': 1,
#           '“—yes,': 1,
#           'that’s': 14,
#           'right': 24,
#           'distance—but': 1,
#           'latitude': 2,
#           'longitude': 2,
#           'got': 45,
#           'to?”': 3,
#           '(alice': 4,
#           'idea': 14,
#           'was,': 14,
#           'either,': 2,
#           'nice': 5,
#           'grand': 2,
#           'words': 14,
#           'say.)': 1,
#           'presently': 2,
#           'began': 46,
#           '_through_': 1,
#           'earth!': 1,
#           'funny': 3,
#           'it’ll': 7,
#           'seem': 7,
#           'among': 12,
#           'people': 13,
#           'walk': 4,
#           'their': 50,
#           'heads': 8,
#           'downward!': 1,
#           'antipathies,': 1,
#           '(she': 9,
#           'rather': 25,
#           'glad': 11,
#           '_was_': 5,
#           'listening,': 2,
#           'time,': 7,
#           'didn’t': 11,
#           'sound': 3,
#           'word)': 1,
#           '“—but': 1,
#           'ask': 7,
#           'them': 49,
#           'name': 9,
#           'country': 4,
#           'is,': 16,
#           'know.': 8,
#           'please,': 4,
#           'ma’am,': 1,
#           'new': 8,
#           'zealand': 1,
#           'australia?”': 1,
#           '(and': 2,
#           'curtsey': 1,
#           'spoke—fancy': 1,
#           '_curtseying_': 1,
#           'you’re': 17,
#           'through': 14,
#           'air!': 1,
#           'do': 68,
#           'could': 64,
#           'manage': 6,
#           'it?)': 1,
#           'ignorant': 1,
#           'girl': 3,
#           'she’ll': 3,
#           'asking!': 1,
#           'no,': 4,
#           'ask:': 1,
#           'perhaps': 12,
#           'written': 9,
#           'somewhere.”': 1,
#           'else': 8,
#           'do,': 8,
#           'soon': 24,
#           'talking': 12,
#           '“dinah’ll': 1,
#           'miss': 1,
#           'to-night,': 1,
#           'should': 29,
#           'think!”': 1,
#           '(dinah': 1,
#           'cat.)': 1,
#           'hope': 4,
#           'remember': 12,
#           'saucer': 1,
#           'milk': 1,
#           'tea-time.': 1,
#           'dinah': 4,
#           'my': 56,
#           'wish': 22,
#           'me!': 3,
#           'are': 59,
#           'mice': 3,
#           'air,': 5,
#           'i’m': 35,
#           'afraid,': 2,
#           'might': 27,
#           'catch': 3,
#           'bat,': 1,
#           'mouse,': 11,
#           'cats': 9,
#           'eat': 16,
#           'bats,': 1,
#           'wonder?”': 3,
#           'sleepy,': 1,
#           'saying': 11,
#           'dreamy': 1,
#           '“do': 8,
#           'bats?': 1,
#           'bats?”': 1,
#           'sometimes,': 1,
#           'bats': 1,
#           'cats?”': 1,
#           'for,': 3,
#           'couldn’t': 9,
#           'answer': 6,
#           'question,': 4,
#           'matter': 8,
#           'which': 47,
#           'felt': 23,
#           'dozing': 1,
#           'off,': 14,
#           'begun': 6,
#           'dream': 3,
#           'walking': 5,
#           'hand': 11,
#           'dinah,': 3,
#           'earnestly,': 1,
#           '“now,': 4,
#           'tell': 29,
#           'truth:': 1,
#           'ever': 16,
#           'bat?”': 1,
#           'suddenly,': 1,
#           'thump!': 2,
#           'came': 38,
#           'heap': 1,
#           'sticks': 1,
#           'dry': 7,
#           'leaves,': 2,
#           'over.': 2,
#           'bit': 8,
#           'hurt,': 1,
#           'jumped': 5,
#           'feet': 11,
#           'moment:': 1,
#           'up,': 10,
#           'overhead;': 1,
#           'passage,': 2,
#           'sight,': 4,
#           'hurrying': 1,
#           'lost:': 1,
#           'wind,': 2,
#           'say,': 5,
#           'turned': 16,
#           'corner,': 2,
#           'ears': 4,
#           'whiskers,': 1,
#           'late': 3,
#           'it’s': 31,
#           'getting!”': 1,
#           'behind': 12,
#           'longer': 2,
#           'seen:': 1,
#           'long,': 1,
#           'low': 7,
#           'hall,': 5,
#           'lit': 1,
#           'row': 2,
#           'lamps': 1,
#           'hanging': 3,
#           'roof.': 1,
#           'doors': 2,
#           'round': 30,
#           'locked;': 1,
#           'been': 36,
#           'side': 12,
#           'other,': 5,
#           'trying': 11,
#           'every': 12,
#           'door,': 9,
#           'walked': 10,
#           'sadly': 2,
#           'middle,': 3,
#           'wondering': 7,
#           'three-legged': 2,
#           'table,': 5,
#           'solid': 1,
#           'glass;': 1,
#           'except': 7,
#           'tiny': 4,
#           'golden': 7,
#           'key,': 3,
#           'first': 30,
#           'belong': 1,
#           'hall;': 1,
#           'but,': 8,
#           'alas!': 3,
#           'locks': 1,
#           'large,': 1,
#           'key': 5,
#           'small,': 1,
#           'any': 71,
#           'rate': 4,
#           'open': 6,
#           'them.': 2,
#           'however,': 20,
#           'second': 6,
#           'round,': 7,
#           'curtain': 1,
#           'before,': 11,
#           'door': 15,
#           'fifteen': 1,
#           'inches': 6,
#           'high:': 3,
#           'lock,': 1,
#           'delight': 1,
#           'fitted!': 1,
#           'opened': 9,
#           'led': 4,
#           'small': 10,
#           'larger': 3,
#           'than': 25,
#           'rat-hole:': 1,
#           'knelt': 1,
#           'along': 5,
#           'passage': 1,
#           'loveliest': 1,
#           'garden': 4,
#           'saw.': 1,
#           'longed': 2,
#           'wander': 1,
#           'those': 11,
#           'beds': 1,
#           'bright': 7,
#           'flowers': 2,
#           'cool': 2,
#           'fountains,': 1,
#           'head': 29,
#           'doorway;': 1,
#           'go': 39,
#           'through,”': 1,
#           'poor': 26,
#           'alice,': 76,
#           '“it': 29,
#           'without': 32,
#           'shoulders.': 1,
#           'oh,': 6,
#           'shut': 4,
#           'telescope!': 1,
#           'only': 46,
#           'knew': 13,
#           'begin.”': 3,
#           'out-of-the-way': 3,
#           'happened': 3,
#           'lately,': 1,
#           'few': 10,
#           'indeed': 3,
#           'really': 9,
#           'impossible.': 1,
#           'waiting': 8,
#           'back': 29,
#           'half': 21,
#           'hoping': 3,
#           'find': 20,
#           'rules': 4,
#           'shutting': 2,
#           'telescopes:': 1,
#           'bottle': 7,
#           '(“which': 1,
#           'certainly': 8,
#           'before,”': 3,
#           'alice,)': 2,
#           'neck': 6,
#           'paper': 4,
#           'label,': 1,
#           '“drink': 3,
#           'me,”': 7,
#           'beautifully': 2,
#           'printed': 3,
#           'letters.': 1,
#           'wise': 2,
#           '_that_': 6,
#           'hurry.': 3,
#           '“no,': 9,
#           'i’ll': 23,
#           'first,”': 2,
#           'said,': 26,
#           'marked': 7,
#           '‘_poison_’': 1,
#           'not”;': 1,
#           'read': 11,
#           'histories': 1,
#           'children': 5,
#           'burnt,': 1,
#           'eaten': 1,
#           'wild': 2,
#           'beasts': 1,
#           'other': 41,
#           'unpleasant': 2,
#           'things,': 2,
#           'because': 13,
#           '_would_': 5,
#           'simple': 5,
#           'friends': 2,
#           'taught': 4,
#           'them:': 1,
#           'as,': 3,
#           'red-hot': 1,
#           'poker': 1,
#           'will': 34,
#           'burn': 2,
#           'hold': 7,
#           'long;': 1,
#           'cut': 5,
#           'your': 62,
#           'finger': 3,
#           'deeply': 1,
#           'knife,': 1,
#           'usually': 2,
#           'bleeds;': 1,
#           'forgotten': 6,
#           'that,': 5,
#           'drink': 4,
#           '“poison,”': 2,
#           'certain': 4,
#           'disagree': 1,
#           'you,': 25,
#           'sooner': 2,
#           'later.': 1,
#           '_not_': 5,
#           'ventured': 4,
#           'taste': 2,
#           'finding': 3,
#           'nice,': 1,
#           '(it': 5,
#           'had,': 1,
#           'fact,': 4,
#           'mixed': 2,
#           'flavour': 1,
#           'cherry-tart,': 1,
#           'custard,': 1,
#           'pine-apple,': 1,
#           'roast': 1,
#           'turkey,': 1,
#           'toffee,': 1,
#           'buttered': 1,
#           'toast,)': 1,
#           'finished': 7,
#           'off.': 5,
#           '*': 64,
#           '“what': 35,
#           'curious': 16,
#           'feeling!”': 1,
#           'alice;': 16,
#           'telescope.”': 1,
#           'indeed:': 1,
#           'now': 25,
#           'ten': 5,
#           'high,': 3,
#           'face': 7,
#           'brightened': 2,
#           'size': 6,
#           'lovely': 2,
#           'garden.': 3,
#           'waited': 9,
#           'minutes': 7,
#           'shrink': 1,
#           'further:': 1,
#           'nervous': 4,
#           'this;': 2,
#           '“for': 7,
#           'end,': 1,
#           'know,”': 8,
#           '“in': 8,
#           'altogether,': 2,
#           'candle.': 1,
#           'then?”': 1,
#           'fancy': 3,
#           'flame': 1,
#           'candle': 2,
#           'blown': 1,
#           'out,': 13,
#           'thing.': 1,
#           'while,': 4,
#           'more': 39,
#           'happened,': 2,
#           'decided': 3,
#           'once;': 1,
#           'alas': 1,
#           'alice!': 3,
#           'table': 8,
#           'possibly': 3,
#           'reach': 4,
#           'it:': 9,
#           'plainly': 1,
#           'glass,': 2,
#           'best': 7,
#           'climb': 1,
#           'legs': 3,
#           'slippery;': 1,
#           'trying,': 1,
#           'thing': 35,
#           'sat': 17,
#           'cried.': 2,
#           '“come,': 9,
#           'there’s': 16,
#           'crying': 2,
#           'that!”': 7,
#           'sharply;': 1,
#           'advise': 1,
#           'leave': 7,
#           'minute!”': 1,
#           'generally': 5,
#           'gave': 15,
#           'advice,': 1,
#           '(though': 1,
#           'seldom': 1,
#           'followed': 8,
#           'it),': 2,
#           'sometimes': 4,
#           'scolded': 1,
#           'severely': 3,
#           'bring': 2,
#           'eyes;': 1,
#           'remembered': 5,
#           'box': 4,
#           'cheated': 1,
#           'game': 6,
#           'croquet': 3,
#           'playing': 2,
#           'against': 10,
#           'child': 3,
#           'fond': 3,
#           'pretending': 1,
#           'two': 21,
#           'people.': 1,
#           '“but': 38,
#           'now,”': 4,
#           '“to': 5,
#           'pretend': 1,
#           'people!': 1,
#           'hardly': 12,
#           'enough': 10,
#           'left': 13,
#           '_one_': 2,
#           'respectable': 1,
#           'person!”': 1,
#           'eye': 4,
#           'glass': 4,
#           'lying': 8,
#           'table:': 1,
#           'cake,': 2,
#           '“eat': 1,
#           'me”': 1,
#           'currants.': 1,
#           '“well,': 20,
#           'it,”': 18,
#           'makes': 12,
#           'grow': 13,
#           'larger,': 3,
#           'can': 37,
#           'key;': 1,
#           'smaller,': 3,
#           'creep': 1,
#           'door;': 1,
#           'garden,': 5,
#           'don’t': 52,
#           'care': 4,
#           'happens!”': 1,
#           'ate': 1,
#           'bit,': 2,
#           'anxiously': 13,
#           '“which': 3,
#           'way?': 1,
#           'way?”,': 1,
#           'holding': 2,
#           'growing,': 4,
#           'surprised': 6,
#           'remained': 3,
#           'same': 22,
#           'size:': 3,
#           'sure,': 2,
#           'happens': 2,
#           'eats': 1,
#           'expecting': 3,
#           'happen,': 1,
#           'dull': 2,
#           'stupid': 1,
#           'life': 2,
#           'common': 1,
#           'way.': 3,
#           'work,': 8,
#           'cake.': 1,
#           '“curiouser': 1,
#           'curiouser!”': 1,
#           'cried': 18,
#           'surprised,': 1,
#           'forgot': 2,
#           'speak': 8,
#           'english);': 1,
#           '“now': 5,
#           'opening': 3,
#           'largest': 1,
#           'telescope': 1,
#           'was!': 1,
#           'good-bye,': 1,
#           'feet!”': 1,
#           '(for': 1,
#           'far': 9,
#           'off).': 1,
#           '“oh,': 19,
#           'shoes': 5,
#           'stockings': 1,
#           'now,': 7,
#           'dears?': 1,
#           'sure': 16,
#           '_i_': 13,
#           'shan’t': 4,
#           'able!': 1,
#           'deal': 11,
#           'myself': 2,
#           'you:': 1,
#           'can;—but': 1,
#           'kind': 6,
#           'them,”': 3,
#           '“or': 6,
#           'won’t': 21,
#           'want': 9,
#           'go!': 1,
#           'pair': 5,
#           'boots': 3,
#           'christmas.”': 1,
#           'planning': 1,
#           '“they': 9,
#           'carrier,”': 1,
#           'thought;': 1,
#           'seem,': 1,
#           'sending': 3,
#           'presents': 2,
#           'one’s': 1,
#           'feet!': 1,
#           'odd': 1,
#           'directions': 1,
#           'look!': 1,
#           '_alice’s': 1,
#           'foot,': 3,
#           'esq.,': 1,
#           'hearthrug,': 1,
#           'fender,_': 1,
#           '(_with': 1,
#           'love_).': 1,
#           'dear,': 6,
#           'nonsense': 1,
#           'talking!”': 1,
#           'struck': 2,
#           'roof': 5,
#           'hall:': 1,
#           'fact': 2,
#           'nine': 4,
#           'door.': 2,
#           'side,': 3,
#           'eye;': 2,
#           'hopeless': 1,
#           'ever:': 1,
#           'cry': 3,
#           '“you': 40,
#           'ashamed': 2,
#           'yourself,”': 1,
#           '“a': 11,
#           'you,”': 6,
#           'this),': 1,
#           'way!': 1,
#           'stop': 4,
#           'moment,': 5,
#           'you!”': 3,
#           'same,': 2,
#           'shedding': 1,
#           'gallons': 1,
#           'tears,': 3,
#           'until': 4,
#           'reaching': 2,
#           'hall.': 1,
#           'heard': 29,
#           'pattering': 3,
#           'distance,': 4,
#           'hastily': 7,
#           'dried': 1,
#           'coming.': 2,
#           'returning,': 1,
#           'splendidly': 1,
#           'dressed,': 1,
#           'kid': 5,
#           'gloves': 5,
#           'fan': 8,
#           'other:': 3,
#           'he': 110,
#           'trotting': 2,
#           'hurry,': 1,
#           'muttering': 3,
#           'himself': 4,
#           'came,': 2,
#           '“oh!': 2,
#           'duchess,': 8,
#           'duchess!': 3,
#           'oh!': 3,
#           'savage': 3,
#           'kept': 13,
#           'waiting!”': 1,
#           'desperate': 1,
#           'ready': 7,
#           'help': 11,
#           'one;': 2,
#           'so,': 7,
#           'began,': 6,
#           'low,': 6,
#           'timid': 3,
#           'voice,': 15,
#           '“if': 21,
#           ...}),
#  Counter({'the': 411,
#           'project': 83,
#           'gutenberg': 24,
#           'ebook': 9,
#           'of': 213,
#           'monster': 6,
#           'maker,': 2,
#           'by': 34,
#           'ray': 4,
#           'bradbury': 4,
#           'this': 80,
#           'is': 44,
#           'for': 56,
#           'use': 12,
#           'anyone': 5,
#           'anywhere': 2,
#           'at': 52,
#           'no': 16,
#           'cost': 2,
#           'and': 223,
#           'with': 77,
#           'almost': 3,
#           'restrictions': 2,
#           'whatsoever.': 2,
#           'you': 110,
#           'may': 15,
#           'copy': 8,
#           'it,': 17,
#           'give': 5,
#           'it': 64,
#           'away': 2,
#           'or': 87,
#           're-use': 2,
#           'under': 8,
#           'terms': 21,
#           'license': 11,
#           'included': 2,
#           'online': 6,
#           'www.gutenberg.org/license': 2,
#           'title:': 1,
#           'maker': 4,
#           'author:': 1,
#           'release': 1,
#           'date:': 1,
#           'july': 1,
#           '6,': 1,
#           '2020': 1,
#           '[ebook': 1,
#           '#62569]': 1,
#           'language:': 1,
#           'english': 1,
#           '***': 6,
#           'start': 2,
#           'produced': 4,
#           'greg': 2,
#           'weeks,': 2,
#           'mary': 2,
#           'meehan': 2,
#           'distributed': 5,
#           'proofreading': 2,
#           'team': 2,
#           'http://www.pgdp.net': 2,
#           '"get': 5,
#           'gunther,"': 1,
#           'official': 4,
#           'orders': 1,
#           'read.': 1,
#           'was': 47,
#           'to': 155,
#           'laugh!': 1,
#           'click': 27,
#           'irish': 9,
#           'were': 12,
#           'marooned': 1,
#           'on': 37,
#           "pirate's": 1,
#           'asteroid--their': 1,
#           'only': 14,
#           'weapons': 1,
#           'a': 182,
#           'single': 1,
#           'gun': 12,
#           'news-reel': 2,
#           'camera.': 4,
#           "[transcriber's": 1,
#           'note:': 1,
#           'etext': 1,
#           'from': 33,
#           'planet': 1,
#           'stories': 1,
#           'spring': 1,
#           '1944.': 1,
#           'extensive': 1,
#           'research': 2,
#           'did': 7,
#           'not': 33,
#           'uncover': 1,
#           'any': 40,
#           'evidence': 1,
#           'that': 57,
#           'u.s.': 7,
#           'copyright': 14,
#           'publication': 1,
#           'renewed.]': 1,
#           'suddenly,': 1,
#           'there.': 3,
#           'there': 16,
#           "wasn't": 4,
#           'time': 3,
#           'blink': 1,
#           'speak': 1,
#           'get': 10,
#           'scared.': 1,
#           "hathaway's": 3,
#           'camera': 16,
#           'loaded': 2,
#           'he': 68,
#           'stood': 5,
#           'listening': 3,
#           'rack-spin': 1,
#           'film': 11,
#           'between': 2,
#           'his': 102,
#           'fingers,': 1,
#           'knew': 3,
#           'getting': 2,
#           'damned': 8,
#           'sweet': 5,
#           'picture': 9,
#           'everything': 3,
#           'happening.': 1,
#           'marnagan': 59,
#           'hunched': 1,
#           'huge': 3,
#           'over': 24,
#           'control-console,': 1,
#           'wrenching': 1,
#           'levers,': 1,
#           'jamming': 1,
#           'studs': 1,
#           'freckled': 3,
#           'fists.': 1,
#           'out': 23,
#           'in': 130,
#           'dark': 2,
#           'fore-part': 1,
#           'space': 2,
#           'star-sprinkling': 1,
#           'meteor': 4,
#           'coming': 3,
#           'like': 18,
#           'blazing': 1,
#           'fury.': 1,
#           'hathaway': 53,
#           'felt': 10,
#           'ship': 7,
#           'move': 2,
#           'him': 10,
#           'sensitive': 1,
#           "animal's": 1,
#           'skin.': 1,
#           'then': 5,
#           'hit.': 1,
#           'made': 4,
#           'spiked': 1,
#           'fist': 1,
#           'knocked': 2,
#           'rear-jets': 1,
#           'flat,': 1,
#           'spun': 2,
#           'cosmic': 5,
#           'merry-go-round.': 1,
#           'plenty': 1,
#           'noise.': 1,
#           'too': 4,
#           'much.': 1,
#           'picked': 1,
#           'up': 18,
#           'hurled': 1,
#           'against': 10,
#           'lever-bank,': 1,
#           'long': 4,
#           'following,': 1,
#           'swearing': 1,
#           'loud': 1,
#           'words.': 1,
#           'remembered': 1,
#           'hanging': 1,
#           'gritting': 1,
#           'keep': 6,
#           'holding': 2,
#           'it.': 16,
#           'what': 15,
#           'shot': 5,
#           'had': 12,
#           'been': 5,
#           'meteor!': 1,
#           'sweeter': 1,
#           'one': 22,
#           'still': 6,
#           'beating': 1,
#           'hell': 2,
#           'controls': 1,
#           'keeping': 3,
#           'words': 1,
#           'himself': 5,
#           'until': 5,
#           'just': 6,
#           'now.': 11,
#           'got': 21,
#           'quiet.': 1,
#           'so': 9,
#           'quiet': 2,
#           'could': 9,
#           'hear': 3,
#           'asteroids': 2,
#           'rushing': 2,
#           'up,': 6,
#           'cold,': 1,
#           'blue': 4,
#           'hard.': 4,
#           'your': 33,
#           'heart': 3,
#           'kicking': 1,
#           'tom-tom': 1,
#           'sick': 2,
#           'stomach': 1,
#           'empty': 1,
#           'lungs.': 1,
#           'stars,': 2,
#           'revolved.': 1,
#           'grabbed': 3,
#           'because': 3,
#           'nearest': 1,
#           'thing,': 1,
#           'held': 4,
#           'on.': 4,
#           'came': 10,
#           'hunting': 1,
#           'space-raider': 1,
#           'ended': 1,
#           'cradled': 1,
#           'slab-sized': 1,
#           "irishman's": 2,
#           'arms,': 1,
#           'diving': 1,
#           'hunk': 2,
#           'metal': 4,
#           'death.': 1,
#           'fade-out!': 1,
#           '"irish!"': 3,
#           'heard': 2,
#           'say.': 1,
#           '"is': 3,
#           'it?"': 2,
#           '_what_?"': 1,
#           'yelled': 3,
#           'inside': 4,
#           'helmet.': 1,
#           'where': 7,
#           'big': 3,
#           'producer': 1,
#           'yells': 1,
#           'cut!?"': 1,
#           'fumed.': 1,
#           '"i\'ll': 4,
#           'die': 2,
#           'when': 11,
#           "i'm": 5,
#           'good': 7,
#           'ready.': 1,
#           'ready': 1,
#           "i'll": 7,
#           'inform': 1,
#           'can': 14,
#           'me': 15,
#           'profile': 4,
#           'films!"': 1,
#           'they': 39,
#           'both': 4,
#           'waited,': 1,
#           'thrust': 1,
#           'shipside': 1,
#           'hand': 3,
#           'gravity;': 1,
#           'each': 3,
#           "other's": 1,
#           'breathing': 3,
#           'hard': 2,
#           'earphones.': 2,
#           'struck,': 1,
#           'once.': 1,
#           'bouncing,': 1,
#           'struck': 3,
#           'again.': 3,
#           'turned': 3,
#           'end': 3,
#           'stopped.': 1,
#           'grabbed;': 1,
#           'rattled': 1,
#           'around--human': 1,
#           'dice': 1,
#           "croupier's": 1,
#           'cup.': 1,
#           'shell': 1,
#           'burst,': 1,
#           'air': 5,
#           'energy': 1,
#           'flung': 3,
#           'out.': 4,
#           'screamed': 1,
#           'lungs,': 1,
#           'but': 18,
#           'brain': 2,
#           'thinking': 3,
#           'quick': 3,
#           'crazy,': 1,
#           'unimportant': 1,
#           'things.': 2,
#           'best': 4,
#           'scenes': 2,
#           'life': 1,
#           'never': 5,
#           'reach': 1,
#           'film,': 2,
#           'an': 20,
#           'audience.': 1,
#           'one,': 2,
#           'dammit!': 2,
#           '_this_': 1,
#           'one!': 1,
#           'spun,': 1,
#           'racketing': 1,
#           'instantaneous,': 1,
#           'flicking': 1,
#           'motions': 1,
#           '*': 50,
#           'silence': 3,
#           'engulfed': 1,
#           'all': 33,
#           'noise,': 1,
#           'ate': 1,
#           'swallowed': 1,
#           'shook': 4,
#           'head,': 1,
#           'instinctively': 1,
#           'locked': 2,
#           'mid-belt.': 2,
#           'nothing': 5,
#           'twisted': 2,
#           'wreckage,': 1,
#           'cold': 2,
#           'pierced': 1,
#           'through': 7,
#           'vac-suit,': 1,
#           'silence.': 2,
#           'wriggled': 1,
#           'wreckage': 1,
#           'into': 18,
#           "didn't": 13,
#           'know': 4,
#           'doing': 4,
#           'found': 5,
#           'fingers': 2,
#           'as': 29,
#           'if': 37,
#           'grown': 1,
#           'born.': 1,
#           'there,': 7,
#           '"well,': 1,
#           'least': 2,
#           'have': 18,
#           'few': 2,
#           'film.': 3,
#           'i\'ll--"': 1,
#           'teetered,': 1,
#           'fell': 3,
#           'crash.': 1,
#           'elevated': 1,
#           'seven': 1,
#           'feet': 3,
#           'bellowing': 2,
#           'manhood': 1,
#           'wreck.': 1,
#           '"hold': 4,
#           'it!"': 2,
#           'cracked': 1,
#           'high': 1,
#           'voice.': 1,
#           'froze.': 1,
#           'whirred.': 2,
#           '"low': 1,
#           'angle': 1,
#           'shot;': 1,
#           'interplanetary': 1,
#           'patrolman': 1,
#           'emerges': 1,
#           'unscathed': 1,
#           'asteroid': 4,
#           'crackup.': 2,
#           'swell': 2,
#           'stuff.': 2,
#           'raise': 1,
#           'this!"': 1,
#           '"from': 1,
#           'toe': 1,
#           'boot!"': 1,
#           'snarled': 1,
#           'brusquely.': 1,
#           'oxen': 1,
#           'shoulders': 2,
#           'flexed': 1,
#           'vac-suit.': 2,
#           '"i': 13,
#           "might've": 1,
#           'died': 1,
#           "nursin'": 1,
#           'film-contraption!"': 1,
#           'funny': 2,
#           'inside,': 2,
#           'suddenly.': 2,
#           'thought': 3,
#           'that.': 2,
#           'die?': 1,
#           'i': 35,
#           'took': 9,
#           'granted': 2,
#           "you'd": 2,
#           'come': 9,
#           'through.': 2,
#           'always': 3,
#           'have.': 1,
#           'funny,': 1,
#           "don't": 9,
#           'think': 10,
#           'about': 24,
#           'dying.': 1,
#           'try': 4,
#           'to."': 1,
#           'stared': 1,
#           'gloved': 2,
#           'hand,': 3,
#           'gloving': 1,
#           'thick': 4,
#           'heavy': 2,
#           "couldn't": 3,
#           'tell': 2,
#           'shaking.': 1,
#           'muscles': 1,
#           'bony': 3,
#           'face': 10,
#           'went': 4,
#           'down,': 4,
#           'pale.': 1,
#           '"where': 3,
#           'are': 29,
#           'we?"': 1,
#           '"a': 5,
#           'million': 1,
#           'miles': 1,
#           'nobody."': 1,
#           'middle': 2,
#           'pocked,': 2,
#           'time-eroded': 1,
#           'plain': 3,
#           'stretched': 1,
#           'off,': 1,
#           'dipping': 1,
#           'down': 14,
#           'silent': 1,
#           'indigo': 1,
#           'rash': 1,
#           'stars.': 1,
#           'overhead,': 1,
#           'sun': 1,
#           'poised;': 1,
#           'black': 1,
#           'stars': 1,
#           'around': 3,
#           'making': 2,
#           'look': 4,
#           'sick.': 1,
#           '"if': 5,
#           'we': 34,
#           'walk': 2,
#           'opposite': 1,
#           'directions,': 1,
#           'hathaway,': 9,
#           "we'd": 2,
#           'be': 39,
#           'shaking': 1,
#           'hands': 3,
#           'other': 17,
#           'side': 2,
#           'rock': 1,
#           'two': 5,
#           'hours."': 1,
#           'mop': 1,
#           'dusty': 1,
#           'red': 6,
#           'hair.': 1,
#           '"and': 3,
#           'promised': 1,
#           'boys': 1,
#           'luna': 1,
#           'base': 2,
#           "i'd": 1,
#           'capture': 2,
#           'gunther': 14,
#           'lad!"': 1,
#           'voice': 6,
#           'stopped': 6,
#           'spoke.': 1,
#           'pumping': 1,
#           'slow,': 1,
#           'hot': 3,
#           'pumps': 1,
#           'blood.': 1,
#           'checked': 1,
#           'my': 11,
#           'oxygen,': 2,
#           'irish.': 13,
#           'sixty': 1,
#           'minutes': 6,
#           'left."': 1,
#           'punctuated': 1,
#           'sentence,': 2,
#           'too.': 1,
#           'upon': 3,
#           'sharp': 2,
#           'meteoric': 1,
#           'rocks': 1,
#           'saw': 4,
#           'tangled': 1,
#           'insides': 2,
#           'radio,': 1,
#           'food': 1,
#           'supply': 1,
#           'mashed': 1,
#           'scattered.': 1,
#           'lucky': 1,
#           'escaped.': 1,
#           '_was_': 1,
#           'suffocation': 1,
#           'better': 5,
#           'death...?': 1,
#           '_sixty': 1,
#           'minutes._': 1,
#           'looked': 4,
#           'another.': 1,
#           '"damn': 2,
#           'meteor!"': 1,
#           'said': 12,
#           'marnagan,': 7,
#           'hotly.': 1,
#           'hold': 2,
#           'idea;': 1,
#           'remembering': 1,
#           'something.': 1,
#           'out:': 1,
#           '"somebody': 1,
#           'tossed': 1,
#           'meteor,': 1,
#           'right': 6,
#           'eye': 1,
#           'rolled': 1,
#           'us,': 2,
#           'poker-hot.': 1,
#           'space-meteors': 1,
#           'glowing.': 1,
#           "it's": 9,
#           'proof': 2,
#           'want,': 1,
#           "i've": 2,
#           'here,': 3,
#           'film."': 1,
#           'winced': 1,
#           'square': 1,
#           'face.': 2,
#           '"it\'s': 3,
#           'need': 2,
#           'now,': 5,
#           'click.': 7,
#           'oxygen.': 2,
#           '_food_.': 1,
#           'some': 4,
#           'way': 6,
#           'back': 8,
#           'earth."': 1,
#           'saying': 3,
#           'thoughts:': 1,
#           '"this': 3,
#           "gunther's": 10,
#           'work.': 6,
#           "he's": 1,
#           'here': 7,
#           'somewhere,': 1,
#           'probably': 4,
#           'laughing': 2,
#           'guts': 1,
#           'job': 1,
#           'us.': 2,
#           'oh,': 4,
#           'god,': 3,
#           'would': 4,
#           'make': 4,
#           'great': 2,
#           'news-release': 1,
#           'stuff': 1,
#           'ever': 5,
#           'earth.': 1,
#           "i.p.'s": 1,
#           'temporarily': 1,
#           'indisposed': 1,
#           'pirate': 2,
#           'whose': 1,
#           'dirty': 2,
#           'has': 3,
#           'seen,': 1,
#           'name,': 1,
#           'finally': 1,
#           'wins': 1,
#           'triumphant': 1,
#           'finish.': 1,
#           'photographed': 1,
#           'spot,': 1,
#           'color,': 2,
#           'yours': 1,
#           'truly,': 1,
#           'hathaway.': 5,
#           'films,': 1,
#           'please': 5,
#           'notice."': 1,
#           'started': 3,
#           'walking,': 1,
#           'fast,': 2,
#           'rubbled': 2,
#           'toward': 5,
#           'ridge': 1,
#           'metal.': 1,
#           'kept': 4,
#           'their': 11,
#           'eyes': 7,
#           'wide': 3,
#           'awake.': 1,
#           'much': 4,
#           'see,': 2,
#           'than': 10,
#           'standing': 2,
#           'still,': 1,
#           'waiting.': 1,
#           'said,': 5,
#           '"we\'re': 1,
#           'working': 1,
#           'margin,': 1,
#           "nothin'": 1,
#           'sweat': 2,
#           'except': 5,
#           'suspicions': 1,
#           'being': 3,
#           'accident.': 1,
#           'fifty': 2,
#           'prove': 1,
#           "you're": 3,
#           'right.': 1,
#           'after': 3,
#           'that--right': 1,
#           "wrong--you'll": 1,
#           'films': 3,
#           'prettiest': 1,
#           'unmoving,': 1,
#           "unbreathin'": 1,
#           'genius.': 2,
#           'talk': 2,
#           'like,': 1,
#           'times': 1,
#           'words,': 2,
#           'our': 11,
#           'tongues.': 1,
#           'scoop.': 1,
#           'me--"': 2,
#           'glossy': 1,
#           '"keeping': 1,
#           'alive': 1,
#           'hobby.': 1,
#           'sort': 2,
#           'two-bit': 1,
#           'death': 5,
#           'order."': 1,
#           'nodded.': 1,
#           '"gunther': 3,
#           'knows': 1,
#           'how': 12,
#           'hate': 1,
#           'dying': 1,
#           'way,': 6,
#           'irony': 1,
#           'clean': 2,
#           "that's": 4,
#           'why': 1,
#           'planned': 1,
#           'crash': 1,
#           'way."': 1,
#           'nothing,': 1,
#           'lips': 3,
#           'corners,': 1,
#           'far': 1,
#           'green': 1,
#           'blazed.': 1,
#           'stopped,': 1,
#           'together.': 1,
#           '"oops!"': 1,
#           'said.': 5,
#           '"hey!"': 1,
#           'blinked.': 1,
#           '"did': 2,
#           'feel': 3,
#           '_that_?"': 1,
#           'body': 4,
#           'feathery,': 1,
#           'light': 3,
#           'whisper,': 1,
#           'boneless': 1,
#           'limbless,': 1,
#           '"irish!': 2,
#           'lost': 2,
#           'weight,': 1,
#           'ridge!"': 1,
#           'ran': 5,
#           'back.': 4,
#           '"let\'s': 1,
#           'again."': 3,
#           'tried': 2,
#           'scowled': 1,
#           'other.': 1,
#           'same': 2,
#           'thing': 2,
#           'happened.': 1,
#           '"gravity': 1,
#           'should': 4,
#           'act': 2,
#           'click."': 1,
#           '"are': 1,
#           'telling': 1,
#           'me?': 1,
#           'man-made.': 1,
#           "that--it's": 1,
#           'gunther!': 1,
#           'wonder': 1,
#           'fast--we': 1,
#           'dragged': 1,
#           'super-gravity': 2,
#           'set-up!': 1,
#           "gunther'd": 1,
#           'do': 27,
#           'anything': 3,
#           'to--did': 1,
#           'say': 3,
#           '_anything_?"': 1,
#           'leaped': 1,
#           'backward': 1,
#           'reaction.': 1,
#           'widened': 2,
#           'jabbing.': 1,
#           'hill-ridge': 1,
#           'swarmed': 2,
#           'brew': 1,
#           'unbelievable': 1,
#           'horrors.': 1,
#           'progeny': 1,
#           "frankenstein's": 1,
#           'ark.': 1,
#           'immense': 3,
#           'crimson': 1,
#           'beasts': 2,
#           'numerous': 2,
#           'legs': 3,
#           'gnashing': 1,
#           'mandibles,': 1,
#           'brown-black': 1,
#           'creatures,': 1,
#           'tubular': 1,
#           'fat,': 1,
#           'others': 1,
#           'thin': 2,
#           'white': 3,
#           'poisonous': 1,
#           'whips': 1,
#           'slashing': 1,
#           'along': 1,
#           'air.': 7,
#           'fangs': 1,
#           'caught': 1,
#           'starlight': 1,
#           'them.': 6,
#           'ran,': 1,
#           'heels,': 1,
#           'lumbering.': 1,
#           'broke': 2,
#           'body.': 1,
#           'things': 5,
#           'rolled,': 1,
#           'slithered': 1,
#           'squirmed': 1,
#           'him.': 8,
#           'blast': 2,
#           'light.': 1,
#           'firing': 1,
#           'proton-gun.': 1,
#           'then,': 7,
#           "click's": 3,
#           'ears,': 1,
#           'incredulous': 1,
#           'bellow.': 1,
#           'hurt': 1,
#           'creatures': 1,
#           'all.': 2,
#           'ridge,': 2,
#           'slid': 2,
#           'incline': 1,
#           'mouth': 1,
#           'small': 6,
#           'cave.': 1,
#           'fella!"': 1,
#           'first,': 1,
#           'behind': 3,
#           '"they\'re': 2,
#           'big;': 1,
#           "can't": 4,
#           'us': 6,
#           'here!"': 1,
#           'gasped': 2,
#           'out,': 3,
#           'squeezed': 1,
#           'two-hundred-fifty': 1,
#           'pounds': 1,
#           'beside': 1,
#           'instinctively,': 1,
#           'added,': 1,
#           '"asteroid': 1,
#           'monsters!': 2,
#           'camera!': 1,
#           'scene!"': 1,
#           'damn': 3,
#           'camera!"': 2,
#           'marnagan.': 3,
#           '"they': 4,
#           'might': 4,
#           'in!"': 1,
#           '"use': 1,
#           'gun."': 1,
#           'impervious': 1,
#           'hides.': 1,
#           'use.': 1,
#           'gahh!': 1,
#           'pretty': 1,
#           'chase,': 1,
#           'eh,': 1,
#           'click?"': 3,
#           '"yeah.': 1,
#           'sure.': 2,
#           '_you_': 4,
#           'enjoyed': 1,
#           'every': 2,
#           'moment': 1,
#           'it."': 2,
#           'that."': 1,
#           'grinned,': 1,
#           'showing': 1,
#           'uneven': 1,
#           'teeth.': 2,
#           '"now,': 1,
#           'will': 13,
#           'these': 10,
#           'uninvited': 1,
#           'guests': 1,
#           'door?"': 1,
#           '"let': 1,
#           'think--"': 1,
#           '"lots': 1,
#           'time,': 1,
#           'little': 5,
#           'man.': 1,
#           'forty': 1,
#           'more': 7,
#           'air,': 1,
#           'exact."': 1,
#           'sat,': 1,
#           'staring': 1,
#           'monsters': 10,
#           'minute.': 1,
#           'something;': 1,
#           'what.': 1,
#           'something': 3,
#           'and--': 1,
#           '"which': 1,
#           'having?"': 1,
#           'asked': 1,
#           'irish,': 1,
#           'casually.': 1,
#           'one?"': 1,
#           'laughed': 2,
#           'nervously.': 1,
#           'pink': 2,
#           'yellow': 3,
#           'ruffles--good': 1,
#           'now': 4,
#           "you've": 1,
#           '_me_': 1,
#           'joking': 1,
#           'death."': 2,
#           '"me': 1,
#           'father': 1,
#           'taught': 1,
#           'me;': 1,
#           "you'll": 1,
#           'luck."': 1,
#           'photographer.': 1,
#           '"i\'m': 1,
#           'anglo-swede,"': 1,
#           'pointed': 2,
#           'shifted': 1,
#           'uneasily.': 2,
#           '"here,': 1,
#           'sitting,': 2,
#           'looking': 3,
#           'boy': 1,
#           'bedroom': 1,
#           'closet,': 1,
#           'take': 4,
#           'beasties': 1,
#           'myself."': 1,
#           'petted': 1,
#           'reluctantly.': 1,
#           '"what': 3,
#           "hell's": 1,
#           'use?': 1,
#           'shot.': 1,
#           "nobody'll": 1,
#           'see': 13,
#           '"then,"': 1,
#           'retorted': 1,
#           '"we\'ll': 3,
#           'develop': 2,
#           'own': 1,
#           'benefit;': 1,
#           'while': 3,
#           "waitin'": 1,
#           'cavalry': 3,
#           'riding': 2,
#           'hill': 1,
#           'rescue!"': 1,
#           'snorted.': 1,
#           '"u.s.': 1,
#           'cavalry."': 1,
#           'raised': 3,
#           'proton-gun': 1,
#           'dramatically.': 1,
#           '"snap': 1,
#           'pose,"': 1,
#           'paid': 7,
#           'salary': 1,
#           'trot': 1,
#           'along,': 1,
#           'photographing,': 1,
#           'hoped,': 1,
#           'gunther,': 3,
#           'record': 1,
#           'peace': 1,
#           'negotiations': 1,
#           'betwixt': 1,
#           'pixies."': 1,
#           'fooling': 1,
#           'anybody.': 1,
#           'superficial': 1,
#           'palaver': 1,
#           'covering': 1,
#           'furious': 1,
#           'running': 4,
#           'red-cropped': 1,
#           'skull.': 1,
#           'played': 1,
#           'palaver,': 1,
#           'too,': 1,
#           'mind': 1,
#           'whirring': 1,
#           'faster': 1,
#           'useless': 1,
#           'animals.': 2,
#           'montage.': 1,
#           'chatting': 2,
#           'monsters.': 3,
#           'smiling': 2,
#           'profile.': 1,
#           'grim,': 1,
#           'without': 9,
#           'effort,': 2,
#           'closeup': 1,
#           'thrashing': 1,
#           'wall': 2,
#           ...}),
#  Counter({'the': 4480,
#           'project': 82,
#           'gutenberg': 24,
#           'ebook': 10,
#           'of': 3681,
#           'pride': 30,
#           'and': 3400,
#           'prejudice,': 2,
#           'by': 645,
#           'jane': 155,
#           'austen': 4,
#           'this': 414,
#           'is': 819,
#           'for': 1021,
#           'use': 23,
#           'anyone': 22,
#           'anywhere': 3,
#           'at': 793,
#           'no': 446,
#           'cost': 6,
#           'with': 1068,
#           'almost': 61,
#           'restrictions': 2,
#           'whatsoever.': 2,
#           'you': 1118,
#           'may': 193,
#           'copy': 8,
#           'it,': 127,
#           'give': 118,
#           'it': 1152,
#           'away': 59,
#           'or': 363,
#           're-use': 2,
#           'under': 37,
#           'terms': 37,
#           'license': 11,
#           'included': 4,
#           'online': 4,
#           'www.gutenberg.org': 2,
#           'title:': 1,
#           'prejudice': 8,
#           'author:': 1,
#           'release': 2,
#           'date:': 1,
#           'august': 1,
#           '26,': 1,
#           '2008': 1,
#           '[ebook': 1,
#           '#1342]': 1,
#           'last': 101,
#           'updated:': 1,
#           'november': 2,
#           '12,': 1,
#           '2019': 1,
#           'language:': 1,
#           'english': 1,
#           'character': 32,
#           'set': 37,
#           'encoding:': 1,
#           'utf-8': 1,
#           '***': 6,
#           'start': 3,
#           'produced': 10,
#           'anonymous': 2,
#           'volunteers,': 2,
#           'david': 2,
#           'widger': 2,
#           'there': 298,
#           'an': 355,
# ...
#           'moonlight': 2,
#           'evening,': 2,
#           'draught,': 1,
#           'shut': 1,
#           'window.': 1,
#           'unreasonably': 1,
#           'angry': 4,
#           'sometimes.': 1,
#           'i’m': 7,
#           'sure': 4,
#           'used': 14,
#           'sensitive.': 1,
#           'due': 1,
#           'condition.': 1,
#           'shall': 8,
#           'neglect': 1,
#           'proper': 1,
#           'self-control;': 1,
#           'pains': 1,
#           'control': 1,
#           'myself,—before': 1,
#           'him,': 3,
#           'least,—and': 1,
#           'tired.': 2,
#           'our': 7,
#           'room': 12,
#           'bit.': 3,
#           'wanted': 3,
#           'downstairs': 2,
#           'opened': 1,
#           'on': 38,
#           'piazza': 1,
#           'roses': 1,
#           'over': 11,
#           'window,': 1,
#           'pretty': 3,
#           'old-fashioned': 2,
#           'chintz': 1,
#           'hangings!': 1,
#           'hear': 2,
#           'only': 15,
#           'window': 5,
#           'two': 5,
#           'beds,': 1,
#           'near': 2,
#           'him': 11,
#           'took': 3,
#           'another.': 2,
#           'careful': 2,
#           'loving,': 1,
#           'hardly': 1,
#           'lets': 2,
#           'stir': 1,
#           'without': 10,
#           'special': 2,
#           'direction.': 2,
#           'schedule': 1,
#           'prescription': 1,
#           'each': 4,
#           'hour': 2,
#           'day;': 1,
#           'takes': 3,
#           'care': 3,
#           'basely': 1,
#           'ungrateful': 1,
#           'value': 1,
#           'more.': 1,
#           'we': 27,
#           'came': 5,
#           'here': 9,
#           'solely': 1,
#           'account,': 1,
#           'perfect': 1,
#           'rest': 4,
#           'air': 4,
#           'could': 12,
#           'get.': 1,
#           '“your': 1,
#           'exercise': 1,
#           'depends': 2,
#           'your': 15,
#           'strength,': 2,
#           'dear,”': 1,
#           'he,': 3,
#           '“and': 3,
#           'food': 1,
#           'somewhat': 1,
#           'appetite;': 1,
#           'absorb': 1,
#           'time.”': 1,
#           'nursery,': 2,
#           'top': 2,
#           'big,': 1,
#           'airy': 2,
#           'room,': 7,
#           'whole': 2,
#           'floor': 2,
#           'nearly,': 1,
#           'windows': 6,
#           'look': 6,
#           'ways,': 1,
#           'sunshine': 1,
#           'galore.': 1,
#           'nursery': 3,
#           'first': 4,
#           'then': 14,
#           'playground': 1,
#           'gymnasium,': 1,
#           'judge;': 1,
#           'barred': 2,
#           'children,': 1,
#           'rings': 1,
#           'walls.': 1,
#           'paint': 1,
#           'as': 58,
#           'boys’': 1,
#           'school': 1,
#           'stripped': 1,
#           'off—the': 1,
#           'paper—in': 1,
#           'patches': 1,
#           'around': 8,
#           'head': 4,
#           'bed,': 4,
#           'far': 2,
#           'reach,': 1,
#           'other': 19,
#           'side': 1,
#           'low': 3,
#           'down.': 2,
#           'worse': 4,
#           'life.': 3,
#           'those': 10,
#           'sprawling': 2,
#           'flamboyant': 1,
#           'patterns': 1,
#           'committing': 1,
#           'every': 5,
#           'artistic': 1,
#           'sin.': 1,
#           'dull': 2,
#           'enough': 6,
#           'confuse': 1,
#           'eye': 1,
#           'following,': 2,
#           'pronounced': 1,
#           'constantly': 1,
#           'irritate,': 1,
#           'provoke': 1,
#           'study,': 1,
#           'when': 26,
#           'follow': 5,
#           'lame,': 2,
#           'uncertain': 1,
#           'curves': 2,
#           'distance': 1,
#           'suddenly': 3,
#           'commit': 1,
#           'suicide—plunge': 1,
#           'off': 15,
#           'outrageous': 1,
#           'angles,': 1,
#           'destroy': 3,
#           'themselves': 1,
#           'unheard-of': 1,
#           'contradictions.': 1,
#           'color': 3,
#           'repellant,': 1,
#           'revolting;': 1,
#           'smouldering,': 1,
#           'unclean': 1,
#           'yellow,': 2,
#           'strangely': 1,
#           'faded': 1,
#           'slow-turning': 1,
#           'sunlight.': 1,
#           'yet': 2,
#           'lurid': 1,
#           'orange': 1,
#           'places,': 1,
#           'sickly': 1,
#           'sulphur': 1,
#           'tint': 1,
#           'others.': 2,
#           'wonder': 5,
#           'children': 5,
#           'hated': 2,
#           'it!': 4,
#           'hate': 2,
#           'live': 2,
#           'long.': 2,
#           'comes': 5,
#           'john,': 2,
#           'must': 19,
#           'away,—he': 1,
#           'hates': 2,
#           'word.': 2,
#           'weeks,': 2,
#           'haven’t': 1,
#           'writing': 6,
#           'before,': 4,
#           'since': 1,
#           'day.': 2,
#           'sitting': 1,
#           'now,': 2,
#           'up': 16,
#           'atrocious': 1,
#           'hinder': 1,
#           'please,': 1,
#           'save': 1,
#           'lack': 2,
#           'strength.': 1,
#           'day,': 4,
#           'nights': 1,
#           'his': 9,
#           'cases': 1,
#           'serious.': 1,
#           'glad': 1,
#           'case': 2,
#           'serious!': 1,
#           'these': 6,
#           'troubles': 1,
#           'dreadfully': 2,
#           'depressing.': 1,
#           'know': 14,
#           'how': 13,
#           'suffer.': 1,
#           'knows': 3,
#           'suffer,': 1,
#           'satisfies': 1,
#           'him.': 3,
#           'course': 7,
#           'nervousness.': 1,
#           'weigh': 2,
#           'duty': 1,
#           'way!': 1,
#           'meant': 2,
#           'help': 5,
#           'real': 2,
#           'comfort,': 2,
#           'comparative': 1,
#           'burden': 1,
#           'already!': 1,
#           'nobody': 5,
#           'effort': 4,
#           'able—to': 1,
#           'dress': 1,
#           'entertain,': 1,
#           'order': 2,
#           'things.': 3,
#           'fortunate': 2,
#           'mary': 1,
#           'baby.': 1,
#           'dear': 4,
#           'baby!': 1,
#           'cannot': 8,
#           'nervous.': 1,
#           'suppose': 3,
#           'wallpaper!': 2,
#           'repaper': 1,
#           'afterwards': 1,
#           'letting': 1,
#           'better': 4,
#           'patient': 1,
#           'than': 12,
#           'way': 7,
#           'fancies.': 1,
#           'after': 5,
#           'changed': 1,
#           'bedstead,': 1,
#           'windows,': 1,
#           'gate': 1,
#           'stairs,': 1,
#           'on.': 1,
#           '“you': 1,
#           'doing': 3,
#           'good,”': 1,
#           'said,': 2,
#           'really,': 2,
#           'dear,': 4,
#           'renovate': 1,
#           'house': 2,
#           'just': 19,
#           'months’': 1,
#           'rental.”': 1,
#           '“then': 1,
#           'us': 2,
#           'go': 13,
#           'downstairs,”': 1,
#           '“there': 1,
#           'rooms': 1,
#           'there.”': 1,
#           'arms': 1,
#           'called': 1,
#           'blessed': 2,
#           'goose,': 1,
#           'cellar': 1,
#           'wished,': 1,
#           'whitewashed': 1,
#           'into': 6,
#           'bargain.': 1,
#           'right': 5,
#           'beds': 1,
#           'comfortable': 1,
#           'need': 1,
#           'wish,': 1,
#           'and,': 1,
#           'silly': 3,
#           'make': 7,
#           'uncomfortable': 1,
#           'whim.': 1,
#           'getting': 8,
#           'fond': 2,
#           'big': 3,
#           'horrid': 2,
#           'paper.': 4,
#           'out': 23,
#           'see': 23,
#           'garden,': 1,
#           'mysterious': 1,
#           'deep-shaded': 1,
#           'arbors,': 3,
#           'riotous': 1,
#           'flowers,': 1,
#           'bushes': 1,
#           'gnarly': 1,
#           'trees.': 1,
#           'another': 4,
#           'lovely': 3,
#           'view': 1,
#           'bay': 1,
#           'private': 1,
#           'wharf': 1,
#           'belonging': 1,
#           'estate.': 1,
#           'shaded': 2,
#           'lane': 1,
#           'runs': 2,
#           'walking': 2,
#           'numerous': 2,
#           'paths': 1,
#           'cautioned': 1,
#           'least.': 1,
#           'imaginative': 1,
#           'power': 1,
#           'habit': 2,
#           'story-making': 1,
#           'weakness': 1,
#           'mine': 1,
#           'lead': 1,
#           'manner': 2,
#           'excited': 1,
#           'fancies,': 1,
#           'ought': 1,
#           'sense': 1,
#           'check': 3,
#           'tendency.': 1,
#           'try.': 3,
#           'relieve': 1,
#           'press': 1,
#           'ideas': 1,
#           'me.': 5,
#           'find': 7,
#           'tired': 5,
#           'discouraging': 1,
#           'advice': 1,
#           'companionship': 1,
#           'work.': 7,
#           'ask': 2,
#           'cousin': 2,
#           'henry': 2,
#           'julia': 1,
#           'visit;': 1,
#           'soon': 2,
#           'fire-works': 1,
#           'pillow-case': 1,
#           'stimulating': 1,
#           'wish': 5,
#           'that.': 1,
#           'looks': 3,
#           'knew': 1,
#           'vicious': 2,
#           'influence': 1,
#           'had!': 1,
#           'recurrent': 1,
#           'spot': 1,
#           'where': 9,
#           'pattern': 17,
#           'lolls': 1,
#           'neck': 1,
#           'bulbous': 2,
#           'eyes': 5,
#           'stare': 1,
#           'upside-down.': 1,
#           'positively': 1,
#           'impertinence': 1,
#           'everlastingness.': 1,
#           'sideways': 1,
#           'crawl,': 1,
#           'absurd,': 1,
#           'unblinking': 1,
#           'everywhere.': 1,
#           'breadths': 1,
#           'didn’t': 4,
#           'match,': 1,
#           'line,': 1,
#           'higher': 1,
#           'other.': 1,
#           'expression': 2,
#           'inanimate': 1,
#           'have!': 2,
#           'lie': 7,
#           'awake': 1,
#           'child': 3,
#           'entertainment': 1,
#           'terror': 1,
#           'blank': 1,
#           'plain': 2,
#           'furniture': 3,
#           'toy-store.': 1,
#           'remember': 1,
#           'kindly': 1,
#           'wink': 1,
#           'knobs': 1,
#           'old': 3,
#           'bureau': 1,
#           'have,': 1,
#           'chair': 2,
#           'seemed': 3,
#           'strong': 2,
#           'friend.': 1,
#           'looked': 6,
#           'fierce': 1,
#           'hop': 1,
#           'safe.': 1,
#           'inharmonious,': 1,
#           'however,': 2,
#           'bring': 1,
#           'downstairs.': 1,
#           'playroom': 1,
#           'out,': 4,
#           'wonder!': 2,
#           'ravages': 1,
#           'made': 2,
#           'here.': 2,
#           'torn': 1,
#           'spots,': 1,
#           'sticketh': 1,
#           'closer': 1,
#           'brother—they': 1,
#           'perseverance': 1,
#           'hatred.': 1,
#           'scratched': 1,
#           'gouged': 1,
#           'splintered,': 1,
#           'plaster': 1,
#           'itself': 1,
#           'dug': 1,
#           'there,': 2,
#           'which': 9,
#           'found': 9,
#           'through': 7,
#           'wars.': 1,
#           'mind': 3,
#           'bit—only': 1,
#           'john’s': 1,
#           'sister.': 1,
#           'girl': 1,
#           'she': 32,
#           'me!': 1,
#           'her': 19,
#           'writing.': 1,
#           'perfect,': 1,
#           'enthusiastic': 1,
#           'housekeeper,': 1,
#           'hopes': 1,
#           'profession.': 1,
#           'verily': 1,
#           'thinks': 1,
#           'windows.': 1,
#           'commands': 1,
#           'lovely,': 1,
#           'shaded,': 1,
#           'winding': 1,
#           'country.': 1,
#           'country,': 2,
#           'elms': 1,
#           'velvet': 1,
#           'meadows.': 1,
#           'kind': 3,
#           'sub-pattern': 1,
#           'different': 2,
#           'shade,': 1,
#           'particularly': 2,
#           'irritating': 1,
#           'one,': 2,
#           'certain': 3,
#           'lights,': 1,
#           'clearly': 2,
#           'then.': 1,
#           'isn’t': 1,
#           'faded,': 1,
#           'sun': 6,
#           'so,': 4,
#           'strange,': 1,
#           'provoking,': 1,
#           'formless': 1,
#           'sort': 2,
#           'figure,': 1,
#           'seems': 4,
#           'sulk': 1,
#           'behind': 8,
#           'conspicuous': 1,
#           'front': 6,
#           'design.': 1,
#           'there’s': 3,
#           'sister': 1,
#           'stairs!': 1,
#           'well,': 1,
#           'fourth': 1,
#           'july': 1,
#           'over!': 1,
#           'gone': 1,
#           'out.': 4,
#           'thought': 5,
#           'might': 3,
#           'company,': 1,
#           'mother': 1,
#           'nellie': 1,
#           'week.': 1,
#           'jennie': 12,
#           'sees': 1,
#           'everything': 3,
#           'same.': 2,
#           'pick': 1,
#           'faster': 2,
#           'send': 2,
#           'weir': 1,
#           'mitchell': 1,
#           'fall.': 1,
#           'want': 11,
#           'all.': 2,
#           'friend': 1,
#           'who': 5,
#           'hands': 1,
#           'once,': 1,
#           'brother,': 1,
#           'so!': 3,
#           'besides,': 2,
#           'undertaking': 1,
#           'far.': 1,
#           'worth': 1,
#           'turn': 3,
#           'hand': 2,
#           'anything,': 1,
#           'fretful': 1,
#           'querulous.': 1,
#           'cry': 2,
#           'nothing,': 1,
#           'time.': 2,
#           'here,': 4,
#           'anybody': 3,
#           'alone.': 2,
#           'deal': 3,
#           'kept': 4,
#           'town': 3,
#           'often': 4,
#           'serious': 1,
#           'cases,': 1,
#           'to.': 3,
#           'walk': 1,
#           'garden': 1,
#           'lane,': 2,
#           'sit': 1,
#           'porch': 1,
#           'roses,': 1,
#           'deal.': 1,
#           'wallpaper.': 4,
#           'perhaps': 2,
#           'because': 5,
#           'dwells': 1,
#           'immovable': 1,
#           'bed—it': 1,
#           'nailed': 2,
#           'down,': 4,
#           'believe—and': 1,
#           'hour.': 2,
#           'gymnastics,': 1,
#           'assure': 1,
#           'you.': 2,
#           'start,': 1,
#           'we’ll': 1,
#           'say,': 1,
#           'bottom,': 1,
#           'corner': 1,
#           'touched,': 2,
#           'determine': 2,
#           'thousandth': 1,
#           'time': 5,
#           'pointless': 1,
#           'conclusion.': 1,
#           'principle': 1,
#           'design,': 1,
#           'arranged': 1,
#           'laws': 8,
#           'radiation,': 1,
#           'alternation,': 1,
#           'repetition,': 1,
#           'symmetry,': 1,
#           'anything': 4,
#           'ever': 7,
#           'heard': 2,
#           'of.': 1,
#           'repeated,': 1,
#           'breadths,': 1,
#           'otherwise.': 1,
#           'breadth': 2,
#           'stands': 1,
#           'bloated': 1,
#           'flourishes—a': 1,
#           '“debased': 1,
#           'romanesque”': 1,
#           'delirium': 1,
#           'tremens—go': 1,
#           'waddling': 2,
#           'isolated': 1,
#           'columns': 1,
#           'fatuity.': 1,
#           'but,': 2,
#           'hand,': 1,
#           'connect': 1,
#           'diagonally,': 1,
#           'outlines': 1,
#           'run': 2,
#           'slanting': 1,
#           'waves': 1,
#           'optic': 1,
#           'horror,': 1,
#           'lot': 3,
#           'wallowing': 1,
#           'seaweeds': 1,
#           'chase.': 1,
#           'goes': 2,
#           'horizontally,': 1,
#           'least': 1,
#           'trying': 4,
#           'distinguish': 1,
#           'its': 7,
#           'going': 2,
#           'horizontal': 1,
#           'frieze,': 1,
#           'adds': 1,
#           'wonderfully': 1,
#           'confusion.': 1,
#           'end': 3,
#           'intact,': 1,
#           'cross-lights': 1,
#           'fade': 1,
#           'shines': 3,
#           'directly': 2,
#           'upon': 4,
#           'radiation': 1,
#           'all,—the': 1,
#           'interminable': 2,
#           'grotesques': 1,
#           'seem': 1,
#           'form': 2,
#           'common': 1,
#           'centre': 1,
#           'rush': 1,
#           'headlong': 1,
#           'plunges': 1,
#           'equal': 1,
#           'distraction.': 1,
#           'nap,': 1,
#           'guess.': 1,
#           'this.': 1,
#           'able.': 1,
#           'absurd.': 1,
#           'way—it': 1,
#           ...})]
